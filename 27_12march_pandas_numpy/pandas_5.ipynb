# %%
import pandas as pd

# %%
d={'col1':[1,2,3,4,5],
  'col2':[45,56,67,34,34],
  'col3':'gyan sid swadhin chandan xxx'.split()}

# %%
df=pd.DataFrame(d,index=list('abcde'))
df
# Out:
#    col1  col2     col3
# a     1    45     gyan
# b     2    56      sid
# c     3    67  swadhin
# d     4    34  chandan
# e     5    34      xxx

# %% [markdown]
# # apply

# %%
#new col "col4" which will be square of values of col1

# %%
df['col4']=df.apply(lambda x: x['col1']**2 , axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4
# a     1    45     gyan     1
# b     2    56      sid     4
# c     3    67  swadhin     9
# d     4    34  chandan    16
# e     5    34      xxx    25

# %%
df['col5']=df['col1']**3

# %%
df
# Out:
#    col1  col2     col3  col4  col5
# a     1    45     gyan     1     1
# b     2    56      sid     4     8
# c     3    67  swadhin     9    27
# d     4    34  chandan    16    64
# e     5    34      xxx    25   125

# %%
#OR

# %%
df['col6']=df['col1'].apply(lambda x:x**3)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6
# a     1    45     gyan     1     1     1
# b     2    56      sid     4     8     8
# c     3    67  swadhin     9    27    27
# d     4    34  chandan    16    64    64
# e     5    34      xxx    25   125   125

# %%
#col7 which holds first letter of col3

# %%
df['col7']=df.apply(lambda x:x['col3'][0] , axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7
# a     1    45     gyan     1     1     1    g
# b     2    56      sid     4     8     8    s
# c     3    67  swadhin     9    27    27    s
# d     4    34  chandan    16    64    64    c
# e     5    34      xxx    25   125   125    x

# %%
df['col8']=df['col3'].str[0]

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8
# a     1    45     gyan     1     1     1    g    g
# b     2    56      sid     4     8     8    s    s
# c     3    67  swadhin     9    27    27    s    s
# d     4    34  chandan    16    64    64    c    c
# e     5    34      xxx    25   125   125    x    x

# %%
df['col9']=df['col3'].apply(lambda x:x[0])

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9
# a     1    45     gyan     1     1     1    g    g    g
# b     2    56      sid     4     8     8    s    s    s
# c     3    67  swadhin     9    27    27    s    s    s
# d     4    34  chandan    16    64    64    c    c    c
# e     5    34      xxx    25   125   125    x    x    x

# %%
#col10 which holds like-- from col3 if g ,keep G else X

# %%
df['col10']=df['col3'].apply(lambda x:'G' if (x[0]=='g' or x[0]=='G') else 'X')

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10
# a     1    45     gyan     1     1     1    g    g    g     G
# b     2    56      sid     4     8     8    s    s    s     X
# c     3    67  swadhin     9    27    27    s    s    s     X
# d     4    34  chandan    16    64    64    c    c    c     X
# e     5    34      xxx    25   125   125    x    x    x     X

# %%
df['col11']=df.apply(lambda x:'M' if (x['col3'][0]=='s' or x['col3'][0]=='g') 
                     else 'X' ,axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11
# a     1    45     gyan     1     1     1    g    g    g     G     M
# b     2    56      sid     4     8     8    s    s    s     X     M
# c     3    67  swadhin     9    27    27    s    s    s     X     M
# d     4    34  chandan    16    64    64    c    c    c     X     X
# e     5    34      xxx    25   125   125    x    x    x     X     X

# %%
#OR

# %%
def func(a):
    if (a[0]=='g' or a[0]=='s'):
        return 'A'
    else :
        return 'B'

# %%
df['col12']=df.apply(lambda x:func(x['col3']),axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B

# %%
#OR

# %%
df['col13']=df['col3'].apply(func)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13
# a     A
# b     A
# c     A
# d     B
# e     B

# %%
#new col where you hold the length of col3 value

# %% [markdown]
# # IMP

# %%
df['col14']=df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13  col14
# a     A      4
# b     A      3
# c     A      7
# d     B      7
# e     B      3

# %%
df['col14_1']=df.apply(lambda x:len(x['col3']), axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13  col14  col15     col16     col17  col14_1
# a     A      4      4  3.806662  3.806662        4
# b     A      3      3  4.025352  4.025352        3
# c     A      7      7  4.204693  4.204693        7
# d     B      7      7  3.526361  3.526361        7
# e     B      3      3  3.526361  3.526361        3

# %%
df['col15']=df['col3'].apply(lambda x:len(x))

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13  col14  col15
# a     A      4      4
# b     A      3      3
# c     A      7      7
# d     B      7      7
# e     B      3      3

# %%
#new col which hold log of col2

# %%
import math

# %%
df['col16']=df['col2'].apply(math.log)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13  col14  col15     col16
# a     A      4      4  3.806662
# b     A      3      3  4.025352
# c     A      7      7  4.204693
# d     B      7      7  3.526361
# e     B      3      3  3.526361

# %%
df['col17']=df.apply(lambda x:math.log(x['col2']) , axis=1)

# %%
df
# Out:
#    col1  col2     col3  col4  col5  col6 col7 col8 col9 col10 col11 col12  \
# a     1    45     gyan     1     1     1    g    g    g     G     M     A
# b     2    56      sid     4     8     8    s    s    s     X     M     A
# c     3    67  swadhin     9    27    27    s    s    s     X     M     A
# d     4    34  chandan    16    64    64    c    c    c     X     X     B
# e     5    34      xxx    25   125   125    x    x    x     X     X     B
#
#   col13  col14  col15     col16     col17
# a     A      4      4  3.806662  3.806662
# b     A      3      3  4.025352  4.025352
# c     A      7      7  4.204693  4.204693
# d     B      7      7  3.526361  3.526361
# e     B      3      3  3.526361  3.526361
