# %%
import pandas as pd

import numpy as np

# %%
np.random.seed(20)

df=pd.DataFrame(np.random.randn(10,4),
             index=pd.date_range('2022-03-10',periods=10),
             columns=list('abcd')
            )

# %%
df
# Out:
#                    a         b         c         d
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new']=df['c']+df['d']

# %%
df.head(3)
# Out:
#                    a         b         c         d       new
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950

# %%
df['sqr_d']=df['d']**2

df.head(3)
# Out:
#                    a         b         c         d       new     sqr_d
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454

# %%
#OR

# %%
df['sqr_d_1']=df['d'].apply(lambda x:x**2)

df.head(3)
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
#
#              sqr_d_1
# 2022-03-10  5.490876
# 2022-03-11  0.957425
# 2022-03-12  0.243454

# %%
#OR

# %%
df['sqr_d_2']=df.apply(lambda x:x['d']**2 ,axis=1)

df.head(3)
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
#
#              sqr_d_1   sqr_d_2
# 2022-03-10  5.490876  5.490876
# 2022-03-11  0.957425  0.957425
# 2022-03-12  0.243454  0.243454

# %%
def test(x):
    if x<0:
        return x
    else:
        return np.log(x)

# %%
df['log_d']=df['d'].apply(test)

df.head(6)
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
#
#              sqr_d_1   sqr_d_2     log_d
# 2022-03-10  5.490876  5.490876 -2.343262
# 2022-03-11  0.957425  0.957425 -0.978481
# 2022-03-12  0.243454  0.243454 -0.493411
# 2022-03-13  0.060376  0.060376 -1.403582
# 2022-03-14  0.165135  0.165135 -0.900495
# 2022-03-15  1.776298  1.776298  0.287266

# %%
#if data in A is +ve return 0,-ve=1

# %%
df['a_1']=df['a'].apply(lambda x:0 if x>=0 else 1) 

df
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186  1.447169  2.421716
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 -1.990073  1.220096
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 -2.547928  2.601737
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 -0.806913  1.291693
#
#              sqr_d_1   sqr_d_2     log_d  a_1
# 2022-03-10  5.490876  5.490876 -2.343262    0
# 2022-03-11  0.957425  0.957425 -0.978481    1
# 2022-03-12  0.243454  0.243454 -0.493411    0
# ...

# %% [markdown]
# # sort_values(by=)

# %%
df.sort_values(by='a',ascending=False)
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 -2.547928  2.601737
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 -0.806913  1.291693
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 -1.990073  1.220096
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186  1.447169  2.421716
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
#
#              sqr_d_1   sqr_d_2     log_d  a_1
# 2022-03-18  2.601737  2.601737 -1.612990    0
# 2022-03-10  5.490876  5.490876 -2.343262    0
# 2022-03-19  1.291693  1.291693 -1.136527    0
# ...

# %% [markdown]
# # convert index to column

# %%
df.T
# Out:
#          2022-03-10  2022-03-11  2022-03-12  2022-03-13  2022-03-14  \
# a          0.883893   -1.084833    0.503097   -0.792017   -0.044195
# b          0.195865    0.559696    0.406414   -0.842368    1.567633
# c          0.357537    0.939469    0.323461   -1.279503    1.051109
# d         -2.343262   -0.978481   -0.493411    0.245715    0.406368
# new       -1.985725   -0.039012   -0.169950   -1.033787    1.457477
# sqr_d      5.490876    0.957425    0.243454    0.060376    0.165135
# sqr_d_1    5.490876    0.957425    0.243454    0.060376    0.165135
# sqr_d_2    5.490876    0.957425    0.243454    0.060376    0.165135
# log_d     -2.343262   -0.978481   -0.493411   -1.403582   -0.900495
# a_1        0.000000    1.000000    0.000000    1.000000    1.000000
#
#          2022-03-15  2022-03-16  2022-03-17  2022-03-18  2022-03-19
# a         -0.168646   -0.243339    0.128778    0.932866    0.527070
# b         -3.189703   -0.130031   -2.066949    2.059838   -1.551101
# ...

# %% [markdown]
# # index as a single column

# %%
df.index
# Out:
# DatetimeIndex(['2022-03-10', '2022-03-11', '2022-03-12', '2022-03-13',
#                '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17',
#                '2022-03-18', '2022-03-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.reset_index()
# Out:
#        index         a         b         c         d       new     sqr_d  \
# 0 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 1 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 3 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 4 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 5 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
# 6 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186  1.447169  2.421716
# 7 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 -1.990073  1.220096
# 8 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 -2.547928  2.601737
# 9 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 -0.806913  1.291693
#
#     sqr_d_1   sqr_d_2     log_d  a_1
# 0  5.490876  5.490876 -2.343262    0
# 1  0.957425  0.957425 -0.978481    1
# 2  0.243454  0.243454 -0.493411    0
# ...

# %%
df2=df.reset_index()
df2
# Out:
#        index         a         b         c         d       new     sqr_d  \
# 0 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 1 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 3 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 4 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 5 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
# 6 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186  1.447169  2.421716
# 7 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 -1.990073  1.220096
# 8 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 -2.547928  2.601737
# 9 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 -0.806913  1.291693
#
#     sqr_d_1   sqr_d_2     log_d  a_1
# 0  5.490876  5.490876 -2.343262    0
# 1  0.957425  0.957425 -0.978481    1
# 2  0.243454  0.243454 -0.493411    0
# ...

# %%
#OR

# %%
df['new_date']=df.index

# %%
df
# Out:
#                    a         b         c         d       new     sqr_d  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 -1.985725  5.490876
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 -0.039012  0.957425
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 -0.169950  0.243454
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 -1.033787  0.060376
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368  1.457477  0.165135
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778  2.452910  1.776298
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186  1.447169  2.421716
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 -1.990073  1.220096
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 -2.547928  2.601737
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 -0.806913  1.291693
#
#              sqr_d_1   sqr_d_2     log_d  a_1   new_date
# 2022-03-10  5.490876  5.490876 -2.343262    0 2022-03-10
# 2022-03-11  0.957425  0.957425 -0.978481    1 2022-03-11
# ...

# %% [markdown]
# # separate year date date from new_date

# %%
df.dtypes
# Out:
# a                  float64
# b                  float64
# c                  float64
# d                  float64
# new                float64
# sqr_d              float64
# sqr_d_1            float64
# sqr_d_2            float64
# log_d              float64
# a_1                  int64
# new_date    datetime64[ns]
# dtype: object

# %%
df.reset_index().dtypes
# Out:
# index       datetime64[ns]
# a                  float64
# b                  float64
# c                  float64
# d                  float64
# new                float64
# sqr_d              float64
# sqr_d_1            float64
# sqr_d_2            float64
# log_d              float64
# a_1                  int64
# new_date    datetime64[ns]
# dtype: object

# %% [markdown]
# # df.index.year

# %%
df.index.year
# Out:
# Int64Index([2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022], dtype='int64')

# %%
df.new_date.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zk/rl6r2z6d34z00g5q8tfywxt00000gn/T/ipykernel_9771/1427399982.py in <module>
# ----> 1 df.new_date.year
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
df['new_date'].dt.year
# Out:
# 2022-03-10    2022
# 2022-03-11    2022
# 2022-03-12    2022
# 2022-03-13    2022
# 2022-03-14    2022
# 2022-03-15    2022
# 2022-03-16    2022
# 2022-03-17    2022
# 2022-03-18    2022
# 2022-03-19    2022
# Freq: D, Name: new_date, dtype: int64

# %% [markdown]
# # pd.DatetimeIndex(df[ ]).year

# %%
df['year']=pd.DatetimeIndex(df['new_date']).year

# %%
df.drop(['sqr_d_1','sqr_d_2','log_d','a_1'],axis=1,inplace=True)
df.drop(['new','sqr_d'],axis=1,inplace=True)

# %%
df['month']=pd.DatetimeIndex(df['new_date']).month

df['day']=pd.DatetimeIndex(df['new_date']).day

# %%
df
# Out:
#                    a         b         c         d   new_date  year  month  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 2022-03-10  2022      3
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 2022-03-11  2022      3
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 2022-03-12  2022      3
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 2022-03-13  2022      3
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368 2022-03-14  2022      3
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778 2022-03-15  2022      3
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186 2022-03-16  2022      3
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 2022-03-17  2022      3
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 2022-03-18  2022      3
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 2022-03-19  2022      3
#
#             day
# 2022-03-10   10
# 2022-03-11   11
# 2022-03-12   12
# 2022-03-13   13
# 2022-03-14   14
# 2022-03-15   15
# 2022-03-16   16
# ...

# %%
#OR

# %% [markdown]
# # df.index.year

# %%
df['year_1']=df.index.year

# %%
df.head()
# Out:
#                    a         b         c         d   new_date  year  month  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 2022-03-10  2022      3
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 2022-03-11  2022      3
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 2022-03-12  2022      3
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 2022-03-13  2022      3
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368 2022-03-14  2022      3
#
#             day  year_1
# 2022-03-10   10    2022
# 2022-03-11   11    2022
# 2022-03-12   12    2022
# 2022-03-13   13    2022
# 2022-03-14   14    2022

# %%
#OR

# %% [markdown]
# # df['new_date'].dt.month

# %%
df['month_1']=df['new_date'].dt.month

# %%
df
# Out:
#                    a         b         c         d   new_date  year  month  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 2022-03-10  2022      3
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 2022-03-11  2022      3
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 2022-03-12  2022      3
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 2022-03-13  2022      3
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368 2022-03-14  2022      3
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778 2022-03-15  2022      3
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186 2022-03-16  2022      3
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 2022-03-17  2022      3
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 2022-03-18  2022      3
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 2022-03-19  2022      3
#
#             day  year_1  month_1
# 2022-03-10   10    2022        3
# 2022-03-11   11    2022        3
# 2022-03-12   12    2022        3
# ...

# %% [markdown]
# # weekday name from date

# %%
df['weekday']=df['new_date'].dt.day_name()

# %%
df
# Out:
#                    a         b         c         d   new_date  year  month  \
# 2022-03-10  0.883893  0.195865  0.357537 -2.343262 2022-03-10  2022      3
# 2022-03-11 -1.084833  0.559696  0.939469 -0.978481 2022-03-11  2022      3
# 2022-03-12  0.503097  0.406414  0.323461 -0.493411 2022-03-12  2022      3
# 2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 2022-03-13  2022      3
# 2022-03-14 -0.044195  1.567633  1.051109  0.406368 2022-03-14  2022      3
# 2022-03-15 -0.168646 -3.189703  1.120132  1.332778 2022-03-15  2022      3
# 2022-03-16 -0.243339 -0.130031 -0.109017  1.556186 2022-03-16  2022      3
# 2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 2022-03-17  2022      3
# 2022-03-18  0.932866  2.059838 -0.934938 -1.612990 2022-03-18  2022      3
# 2022-03-19  0.527070 -1.551101  0.329613 -1.136527 2022-03-19  2022      3
#
#             day  year_1  month_1    weekday
# 2022-03-10   10    2022        3   Thursday
# 2022-03-11   11    2022        3     Friday
# ...

# %%
df.index.day_name()
# Out:
# Index(['Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Saturday'],
#       dtype='object')

# %%
#groupby operation on day n count

# %%
df.groupby('weekday').size()
# Out:
# weekday
# Friday       2
# Monday       1
# Saturday     2
# Sunday       1
# Thursday     2
# Tuesday      1
# Wednesday    1
# dtype: int64

# %%
df.groupby('weekday').size()
# Out:
# weekday
# Friday       2
# Monday       1
# Saturday     2
# Sunday       1
# Thursday     2
# Tuesday      1
# Wednesday    1
# dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# Thursday     2
# Friday       2
# Saturday     2
# Sunday       1
# Monday       1
# Tuesday      1
# Wednesday    1
# Name: weekday, dtype: int64

# %%
df3
# Out:
# '     index         a         b         c         d   new_date  year  month  day  year_1  month_1\n2022-03-10  0.883893  0.195865  0.357537 -2.343262 2022-03-10  2022      3   10    2022        3\n2022-03-11 -1.084833  0.559696  0.939469 -0.978481 2022-03-11  2022      3   11    2022        3\n2022-03-12  0.503097  0.406414  0.323461 -0.493411 2022-03-12  2022      3   12    2022        3\n2022-03-13 -0.792017 -0.842368 -1.279503  0.245715 2022-03-13  2022      3   13    2022        3\n2022-03-14 -0.044195  1.567633  1.051109  0.406368 2022-03-14  2022      3   14    2022        3\n2022-03-15 -0.168646 -3.189703  1.120132  1.332778 2022-03-15  2022      3   15    2022        3\n2022-03-16 -0.243339 -0.130031 -0.109017  1.556186 2022-03-16  2022      3   16    2022        3\n2022-03-17  0.128778 -2.066949 -0.885493 -1.104579 2022-03-17  2022      3   17    2022        3\n2022-03-18  0.932866  2.059838 -0.934938 -1.612990 2022-03-18  2022      3   18    2022        3\n2022-03-19  0.527
# ...

# %%
import numpy as np
exam_data32={'name':['Anastasia','Dima','Katherine','James','Emily','Michael','Matthew','Laura','Kevin','Jonas'],'score':[12.5,9,16.5,np.nan,9,20,14.5,np.nan,8,19],
         'attempts':[1,3,2,3,2,3,1,1,2,1],'qualify':['yes','no','yes','no','no','yes','yes','no','no','yes']}

df32=pd.DataFrame(exam_data32)  
df32
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
print('index in column')
df32.reset_index(inplace=True)
print(df32)
# Out:
# index in column
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin    8.0         2      no
# 9      9      Jonas   19.0         1     yes

# %%
print('hiding index')
df32.to_string(index=False)
# Out:
# hiding index
# ' index      name  score  attempts qualify\n     0 Anastasia   12.5         1     yes\n     1      Dima    9.0         3      no\n     2 Katherine   16.5         2     yes\n     3     James    NaN         3      no\n     4     Emily    9.0         2      no\n     5   Michael   20.0         3     yes\n     6   Matthew   14.5         1     yes\n     7     Laura    NaN         1      no\n     8     Kevin    8.0         2      no\n     9     Jonas   19.0         1     yes'

# %%
type(df32.to_string(index=False))
# Out:
# str

# %%
print(df32.to_string(index=False))
# Out:
#  index      name  score  attempts qualify
#      0 Anastasia   12.5         1     yes
#      1      Dima    9.0         3      no
#      2 Katherine   16.5         2     yes
#      3     James    NaN         3      no
#      4     Emily    9.0         2      no
#      5   Michael   20.0         3     yes
#      6   Matthew   14.5         1     yes
#      7     Laura    NaN         1      no
#      8     Kevin    8.0         2      no
#      9     Jonas   19.0         1     yes

# %%
df33=print(df32.to_string(index=False))

df33
# Out:
#  index      name  score  attempts qualify
#      0 Anastasia   12.5         1     yes
#      1      Dima    9.0         3      no
#      2 Katherine   16.5         2     yes
#      3     James    NaN         3      no
#      4     Emily    9.0         2      no
#      5   Michael   20.0         3     yes
#      6   Matthew   14.5         1     yes
#      7     Laura    NaN         1      no
#      8     Kevin    8.0         2      no
#      9     Jonas   19.0         1     yes

# %%
type(df33)
# Out:
# NoneType

# %%
df34=pd.DataFrame(df33)

# %%
type(df34)
# Out:
# pandas.core.frame.DataFrame

# %%
df34
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zk/rl6r2z6d34z00g5q8tfywxt00000gn/T/ipykernel_9771/394617393.py in <module>
#       1 d=df32.to_string(index=False)
# ----> 2 df35=pd.DataFrame(d)
#       3
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!
