# %%
import pandas as pd
import numpy as np
import json

# %%
df=pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv"
              ,sep=',')

df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
dy=df.dtypes

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy['Name']
# Out:
# dtype('O')

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Age','Sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
#dataset from age column starting from 5th index to 100 index

# %%
df['Age'][5:100]
# Out:
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 95, dtype: float64

# %%
#access every 2nd data in age

# %%
df['Age'][::2].head(3)
# Out:
# 0    22.0
# 2    26.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# # null age values

# %%
import numpy as np

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# # describe()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.columns[df.dtypes=='object'].tolist()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # df with only object datatype

# %%
df[df.columns[df.dtypes=='object']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#OR

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#OR

#df[[column list]]

# %%
df_category=df[df.columns[df.dtypes=='object'].tolist()]

df_category
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df_category.describe()
# Out:
#                            Name   Sex Ticket        Cabin Embarked
# count                       156   156    156           31      155
# unique                      156     2    145           28        3
# top     Braund, Mr. Owen Harris  male   2651  C23 C25 C27        S
# freq                          1   100      2            2      110

# %% [markdown]
# # list if indexes where age is null

# %%
np.where(df['Age'].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154]),)

# %%
df_age_null=np.where(df['Age'].isnull()==True)

# %%
df_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154]),)

# %% [markdown]
# # df with indexes where age is null

# %%
df.iloc[df_age_null]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
df.iloc[5:7]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 5            6         0       3         Moran, Mr. James  male   NaN      0
# 6            7         0       1  McCarthy, Mr. Timothy J  male  54.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S

# %%
df.iloc[5:7,3]
# Out:
# 5           Moran, Mr. James
# 6    McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %% [markdown]
# # who paid highest fare

# %%
df[['Name','Fare']][df['Fare']==df['Fare'].max()]
# Out:
#                               Name   Fare
# 27  Fortune, Mr. Charles Alexander  263.0
# 88      Fortune, Miss. Mabel Helen  263.0

# %%
#OR
df.iloc[np.where(df['Fare']==max(df['Fare']))]['Name']
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %% [markdown]
# # age is 24

# %%
df[["Name","Age"]][df['Age']==24]
# Out:
#                                                   Name   Age
# 89                              Celotti, Mr. Francesco  24.0
# 118                           Baxter, Mr. Quigg Edmond  24.0
# 127                          Madsen, Mr. Fridtjof Arne  24.0
# 139                                 Giglio, Mr. Victor  24.0
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  24.0

# %% [markdown]
# # min age

# %%
df[df['Age']==df['Age'].min()]
# Out:
#     PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 78           79         1       2  Caldwell, Master. Alden Gates  male  0.83
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 78      0      2  248738  29.0   NaN        S

# %% [markdown]
# # who cabin is nan

# %%
df[['Name','Age','Cabin']][df['Cabin'].isnull()]
# Out:
#                                 Name   Age Cabin
# 0            Braund, Mr. Owen Harris  22.0   NaN
# 2             Heikkinen, Miss. Laina  26.0   NaN
# 4           Allen, Mr. William Henry  35.0   NaN
# 5                   Moran, Mr. James   NaN   NaN
# 7     Palsson, Master. Gosta Leonard   2.0   NaN
# ..                               ...   ...   ...
# 150       Bateman, Rev. Robert James  51.0   NaN
# 152                 Meo, Mr. Alfonzo  55.5   NaN
# 153  van Billiard, Mr. Austin Blyler  40.5   NaN
# 154            Olsen, Mr. Ole Martin   NaN   NaN
# 155      Williams, Mr. Charles Duane  51.0   NaN
#
# [125 rows x 3 columns]

# %% [markdown]
# # where survived is male

# %%
df[['Name','Sex']][(df['Survived']==1) & (df['Sex']=='male')]
# Out:
#                                              Name   Sex
# 17                   Williams, Mr. Charles Eugene  male
# 21                          Beesley, Mr. Lawrence  male
# 23                   Sloper, Mr. William Thompson  male
# 36                               Mamee, Mr. Hanna  male
# 55                              Woolner, Mr. Hugh  male
# 65                       Moubarek, Master. Gerios  male
# 74                                  Bing, Mr. Lee  male
# 78                  Caldwell, Master. Alden Gates  male
# 81                    Sheerlinck, Mr. Jan Baptist  male
# 97                Greenfield, Mr. William Bertram  male
# 107                        Moss, Mr. Albert Johan  male
# 125                  Nicola-Yarred, Master. Elias  male
# 127                     Madsen, Mr. Fridtjof Arne  male
# 146  Andersson, Mr. August Edvard ("Wennerstrom")  male

# %%
#reset index

# %%
df[['Name','Sex']][(df['Survived']==1) & (df['Sex']=='male')].reset_index()
# Out:
#     index                                          Name   Sex
# 0      17                  Williams, Mr. Charles Eugene  male
# 1      21                         Beesley, Mr. Lawrence  male
# 2      23                  Sloper, Mr. William Thompson  male
# 3      36                              Mamee, Mr. Hanna  male
# 4      55                             Woolner, Mr. Hugh  male
# 5      65                      Moubarek, Master. Gerios  male
# 6      74                                 Bing, Mr. Lee  male
# 7      78                 Caldwell, Master. Alden Gates  male
# 8      81                   Sheerlinck, Mr. Jan Baptist  male
# 9      97               Greenfield, Mr. William Bertram  male
# 10    107                        Moss, Mr. Albert Johan  male
# 11    125                  Nicola-Yarred, Master. Elias  male
# 12    127                     Madsen, Mr. Fridtjof Arne  male
# 13    146  Andersson, Mr. August Edvard ("Wennerstrom")  male

# %% [markdown]
# # reset_index()

# %%
df[['Name','Sex']][(df['Survived']==1) & (df['Sex']=='male')].reset_index().drop('index',axis=1)
# Out:
#                                             Name   Sex
# 0                   Williams, Mr. Charles Eugene  male
# 1                          Beesley, Mr. Lawrence  male
# 2                   Sloper, Mr. William Thompson  male
# 3                               Mamee, Mr. Hanna  male
# 4                              Woolner, Mr. Hugh  male
# 5                       Moubarek, Master. Gerios  male
# 6                                  Bing, Mr. Lee  male
# 7                  Caldwell, Master. Alden Gates  male
# 8                    Sheerlinck, Mr. Jan Baptist  male
# 9                Greenfield, Mr. William Bertram  male
# 10                        Moss, Mr. Albert Johan  male
# 11                  Nicola-Yarred, Master. Elias  male
# 12                     Madsen, Mr. Fridtjof Arne  male
# 13  Andersson, Mr. August Edvard ("Wennerstrom")  male

# %% [markdown]
# # numpy array

# %%
arr=np.random.randn(3,4)

arr
# Out:
# array([[ 0.66577507, -2.08061118, -0.6728821 ,  1.23461317],
#        [-0.21911931, -0.51380849, -1.0596483 ,  0.6537203 ],
#        [ 0.70111588,  0.31844607, -0.50935159,  0.15662227]])

# %%
np_df=pd.DataFrame(arr)

np_df
# Out:
#           0         1         2         3
# 0  0.665775 -2.080611 -0.672882  1.234613
# 1 -0.219119 -0.513808 -1.059648  0.653720
# 2  0.701116  0.318446 -0.509352  0.156622

# %%
np.array([4,5,6,7,89])
# Out:
# array([ 4,  5,  6,  7, 89])

# %%
pd.Series(np.array([8,5,6,3,9]))
# Out:
# 0    8
# 1    5
# 2    6
# 3    3
# 4    9
# dtype: int64

# %%
new_df=pd.Series(np.array([5,6,7,89,2]),index=['a','b','c','d','e'])

new_df
# Out:
# a     5
# b     6
# c     7
# d    89
# e     2
# dtype: int64

# %% [markdown]
# # loc  -- index name

# %%
new_df.loc['a']
# Out:
# 5

# %%
new_df.loc[['a','c']]
# Out:
# a    5
# c    7
# dtype: int64

# %% [markdown]
# # iloc  --index position(integer)

# %%
new_df.iloc[0]
# Out:
# 5

# %%
new_df.iloc[[0,2]]
# Out:
# a    5
# c    7
# dtype: int64

# %%
new_df.loc[['a','c']]
# Out:
# a    5
# c    7
# dtype: int64

# %%
df_1=pd.DataFrame(np.random.randint(0,2,(3,5)))

df_1
# Out:
#    0  1  2  3  4
# 0  0  1  1  0  1
# 1  1  1  0  1  0
# 2  0  0  1  0  0

# %% [markdown]
# # rename

# %%
df_1=df_1.rename(columns={0:'x',1:'y',2:'z',3:'m',4:'n'})

# %% [markdown]
# # rename index

# %%
df_1.rename(index={0:'a',1:'b',2:'c'},inplace=True)

# %%
df_1
# Out:
#    x  y  z  m  n
# a  0  1  1  0  1
# b  1  1  0  1  0
# c  0  0  1  0  0

# %%
#give me z-m :b-c value

# %%
df_1.loc[['b','c'],['z','m']]
# Out:
#    z  m
# b  0  1
# c  1  0

# %%
df_1.iloc[1:,2:4]
# Out:
#    z  m
# b  0  1
# c  1  0

# %%
df_1['new']=df_1['m']+df_1['n']

# %%
df_1
# Out:
#    x  y  z  m  n  new
# a  0  1  1  0  1    1
# b  1  1  0  1  0    1
# c  0  0  1  0  0    0

# %% [markdown]
# # drop(axis=1/0)

# %%
df_1.drop('x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zk/rl6r2z6d34z00g5q8tfywxt00000gn/T/ipykernel_16808/436621575.py in <module>
# ----> 1 df_1.drop('x')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df_1.drop('new',axis=1,inplace=True)

# %%
df_1
# Out:
#    x  y  z  m  n
# a  0  1  1  0  1
# b  1  1  0  1  0
# c  0  0  1  0  0

# %%
df_1.drop('c') #axis=0
# Out:
#    x  y  z  m  n
# a  0  1  1  0  1
# b  1  1  0  1  0

# %% [markdown]
# # np.random.seed(23)--- same random data

# %%
np.random.seed(23)

df1=pd.DataFrame(np.random.randn(4,5),index=list('abcd'),columns=list('xyzuv'))

df1
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %% [markdown]
# # extract -ve data

# %%
df1[df1<0]
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df1.values
# Out:
# array([[ 0.66698806,  0.02581308, -0.77761941,  0.94863382,  0.70167179],
#        [-1.05108156, -0.36754812, -1.13745969, -1.32214752,  1.77225828],
#        [-0.34745899,  0.67014016,  0.32227152,  0.06034293, -1.04345   ],
#        [-1.00994188,  0.44173637,  1.12887685, -1.83806777, -0.93876863]])

# %%
df1.values[df1.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %% [markdown]
# # for every -ve value get the row ,column name

# %%
for i in df1.index:
    for j in df1.columns:
        if df1.loc[i,j]<0:
            print(i,j,df1.loc[i,j])
# Out:
# a z -0.7776194131918178
# b x -1.0510815639071178
# b y -0.3675481161171661
# b z -1.1374596907250272
# b u -1.3221475225908594
# c x -0.34745899102186334
# c v -1.0434500017467254
# d x -1.0099418765878465
# d u -1.8380677677579502
# d v -0.9387686311201282

# %%
d={'key1':[1,2,3,4,np.nan],'key2':['gyan','dpu',5,6,7],'key3':[5,np.nan,np.nan,np.nan,np.nan]}

df=pd.DataFrame(d)

df
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0
# 1   2.0   dpu   NaN
# 2   3.0     5   NaN
# 3   4.0     6   NaN
# 4   NaN     7   NaN

# %% [markdown]
# # df.dropna()

# %%
df.dropna() #axis=0 default
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0

# %%
df.dropna(axis=1)
# Out:
#    key2
# 0  gyan
# 1   dpu
# 2     5
# 3     6
# 4     7

# %% [markdown]
# # thresh

# %%
df.dropna(thresh=0) #Require that many non-NA values.(0 non NA value)
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0
# 1   2.0   dpu   NaN
# 2   3.0     5   NaN
# 3   4.0     6   NaN
# 4   NaN     7   NaN

# %%
df.dropna(thresh=1)
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0
# 1   2.0   dpu   NaN
# 2   3.0     5   NaN
# 3   4.0     6   NaN
# 4   NaN     7   NaN

# %%
df.dropna(thresh=3)
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0

# %% [markdown]
# # fillna(value=)

# %%
df.fillna(100)
# Out:
#     key1  key2   key3
# 0    1.0  gyan    5.0
# 1    2.0   dpu  100.0
# 2    3.0     5  100.0
# 3    4.0     6  100.0
# 4  100.0     7  100.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0
# 1   2.0   dpu   2.5
# 2   3.0     5   2.5
# 3   4.0     6   2.5
# 4   2.5     7   2.5

# %%
df
# Out:
#    key1  key2  key3
# 0   1.0  gyan   5.0
# 1   2.0   dpu   NaN
# 2   3.0     5   NaN
# 3   4.0     6   NaN
# 4   NaN     7   NaN

# %%
df['key1'].fillna(value=df['key1'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    2.5
# Name: key1, dtype: float64

# %%
df['key3'].fillna(value=df['key3'].mean())
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: key3, dtype: float64

# %% [markdown]
# # groupby

# %%
data={'name':['gyana','nanda','chandan','swaraj','swadhin','balaram','bighna','aneesh','chandu','surya','tabu','pati','shiba'],
      'city':['angul','jagatsinghpur','jharsuguda','angul','angul','puri','angul','sambalpur','baripada','jajpur','jharsuguda','jajpur','baripada']}

df=pd.DataFrame(data)

df
# Out:
#        name           city
# 0     gyana          angul
# 1     nanda  jagatsinghpur
# 2   chandan     jharsuguda
# 3    swaraj          angul
# 4   swadhin          angul
# 5   balaram           puri
# 6    bighna          angul
# 7    aneesh      sambalpur
# 8    chandu       baripada
# 9     surya         jajpur
# 10     tabu     jharsuguda
# 11     pati         jajpur
# 12    shiba       baripada

# %%
df.groupby('city')

# %%
df.groupby('city').size()
# Out:
# city
# angul            4
# baripada         2
# jagatsinghpur    1
# jajpur           2
# jharsuguda       2
# puri             1
# sambalpur        1
# dtype: int64

# %%
df.groupby(['city']).size().reset_index(name="no of people")
# Out:
#             city  no of people
# 0          angul             4
# 1       baripada             2
# 2  jagatsinghpur             1
# 3         jajpur             2
# 4     jharsuguda             2
# 5           puri             1
# 6      sambalpur             1

# %%
df.groupby('city').describe()
# Out:
#                name
#               count unique      top freq
# city
# angul             4      4    gyana    1
# baripada          2      2   chandu    1
# jagatsinghpur     1      1    nanda    1
# jajpur            2      2    surya    1
# jharsuguda        2      2  chandan    1
# puri              1      1  balaram    1
# sambalpur         1      1   aneesh    1

# %% [markdown]
# # Transpose( .T )

# %%
df
# Out:
#        name           city
# 0     gyana          angul
# 1     nanda  jagatsinghpur
# 2   chandan     jharsuguda
# 3    swaraj          angul
# 4   swadhin          angul
# 5   balaram           puri
# 6    bighna          angul
# 7    aneesh      sambalpur
# 8    chandu       baripada
# 9     surya         jajpur
# 10     tabu     jharsuguda
# 11     pati         jajpur
# 12    shiba       baripada

# %%
df.T
# Out:
#          0              1           2       3        4        5       6   \
# name  gyana          nanda     chandan  swaraj  swadhin  balaram  bighna
# city  angul  jagatsinghpur  jharsuguda   angul    angul     puri   angul
#
#              7         8       9           10      11        12
# name     aneesh    chandu   surya        tabu    pati     shiba
# city  sambalpur  baripada  jajpur  jharsuguda  jajpur  baripada

# %%
arr1=np.random.randn(3,4)

# %%
arr2=np.random.randn(3,4)

# %%
arr3=np.random.randn(3,4)

# %%
df1=pd.DataFrame(arr1,columns=list('ABCD'),index=[0,1,2])

# %%
df2=pd.DataFrame(arr2,columns=list('ABCD'),index=[0,1,2])

df3=pd.DataFrame(arr3,columns=list('ABCD'),index=[0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620

# %%
df3
# Out:
#           A         B         C         D
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %% [markdown]
# # concat 3 dfs(horizontally,vertically)

# %%
#horizontally

# %%
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %% [markdown]
# # ignore_index

# %%
pd.concat([df1,df2,df3],ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
#vertically

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.728876  1.968435 -0.547788
# 1  0.241106 -0.952510 -0.136267  1.267248 -2.506230  0.146960  0.606195
# 2  0.173634 -1.223255  1.415320  0.457711  0.013422  0.935945  0.420623
#
#           D         A         B         C         D
# 0 -0.679418 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.022539 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.411620  0.512137  0.131538 -0.331617 -1.632386

# %%
df1=pd.DataFrame(arr1,columns=list('ABCD'),index=[0,1,2])
df2=pd.DataFrame(arr2,columns=list('ABCD'),index=[3,4,5])

df3=pd.DataFrame(arr3,columns=list('ABCD'),index=[6,7,8])

# %%
pd.concat( [df1,df2,df3],axis=1).fillna(value='X')
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119         X         X         X
# 1  0.241106  -0.95251 -0.136267  1.267248         X         X         X
# 2  0.173634 -1.223255   1.41532  0.457711         X         X         X
# 3         X         X         X         X  0.728876  1.968435 -0.547788
# 4         X         X         X         X  -2.50623   0.14696  0.606195
# 5         X         X         X         X  0.013422  0.935945  0.420623
# 6         X         X         X         X         X         X         X
# 7         X         X         X         X         X         X         X
# 8         X         X         X         X         X         X         X
#
#           D         A         B         C         D
# 0         X         X         X         X         X
# 1         X         X         X         X         X
# 2         X         X         X         X         X
# ...

# %% [markdown]
# # merge

# %%
employee=[(1,'name1'),(3,'name3'),(2,'name2')]

dept=[(2,'science','bbsr'),(1,'arts','angul'),(5,'eco','bari')]

df1=pd.DataFrame(employee,columns=['empid','name'])
print(df1)
df2=pd.DataFrame(dept,columns=['empid','course','location'])
print(df2)

df3=pd.merge(df1,df2,on='empid')

df3
# Out:
#    empid   name
# 0      1  name1
# 1      3  name3
# 2      2  name2
#    empid   course location
# 0      2  science     bbsr
# 1      1     arts    angul
# 2      5      eco     bari
#    empid   name   course location
# 0      1  name1     arts    angul
# 1      2  name2  science     bbsr

# %%
#left join

# %%
pd.merge(df1,df2,on='empid',how='left')
# Out:
#    empid   name   course location
# 0      1  name1     arts    angul
# 1      3  name3      NaN      NaN
# 2      2  name2  science     bbsr

# %%
#right

# %%
pd.merge(df1,df2,on='empid',how='right')
# Out:
#    empid   name   course location
# 0      2  name2  science     bbsr
# 1      1  name1     arts    angul
# 2      5    NaN      eco     bari

# %%
#outer

# %%
pd.merge(df1,df2,on='empid',how='outer')
# Out:
#    empid   name   course location
# 0      1  name1     arts    angul
# 1      3  name3      NaN      NaN
# 2      2  name2  science     bbsr
# 3      5    NaN      eco     bari

# %%
import pandas as pd
employee=[(1,'name1'),(3,'name3'),(2,'name2')]

dept=[(2,'science','bbsr'),(1,'arts','angul'),(5,'eco','bari')]

df1=pd.DataFrame(employee,columns=['empid','name'])
df2=pd.DataFrame(dept,columns=['empid_id','course','location'])

df3=pd.merge(df1,df2,left_on=['empid'],right_on=['emp_id'])

df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zk/rl6r2z6d34z00g5q8tfywxt00000gn/T/ipykernel_17655/1166632252.py in <module>
#       7 df2=pd.DataFrame(dept,columns=['empid_id','course','location'])
#       8
# ----> 9 df3=pd.merge(df1,df2,left_on=['empid'],right_on=['emp_id'])
#      10
#      11 df3
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
