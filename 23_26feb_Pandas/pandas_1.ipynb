# %%
import pandas as pd

# %%
df=pd.read_csv('names.csv')

df
# Out:
#    First name Last Name                Email  Age
# 0  Gyanajyoti   Pradhan  Gyana.dpu@gmail.com   29
# 1    Sidharth     Nanda        sid@gmail.com   30
# 2       Surya     Sahoo       sura@gmail.com   29

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#https://github.com/codeforamerica/ohana-api

df=pd.read_csv('sample-csv/taxonomy.csv')

df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#lets delete the first row,it will take first record as column names

# %%
df=pd.read_csv('sample-csv/taxonomy.csv')

df
# Out:
#            101                     Emergency Unnamed: 2            Unnamed: 3
# 0       101-01             Disaster Response        101             Emergency
# 1       101-02                Emergency Cash        101             Emergency
# 2    101-02-01             Help Pay for Food     101-02        Emergency Cash
# 3    101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# 4    101-02-03          Help Pay for Housing     101-02        Emergency Cash
# ..         ...                           ...        ...                   ...
# 284  111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 285     111-02                     Mediation        111                 Legal
# 286     111-03                        Notary        111                 Legal
# 287     111-04                Representation        111                 Legal
# 288     111-05  Translation & Interpretation        111                 Legal
#
# [289 rows x 4 columns]

# %% [markdown]
# # header

# %%
df=pd.read_csv('sample-csv/taxonomy.csv',header=None)

df
# Out:
#              0                             1       2                     3
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# # custome column name

# %%
df=pd.read_csv('sample-csv/taxonomy.csv',names=['taxonomy_id','name','parent_id','parent_name'])

df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# # Rename column name : df.rename( { } )

# %%
df.columns
# Out:
# Index(['taxonomy_id', 'name', 'parent_id', 'parent_name'], dtype='object')

# %%
df.rename(columns={'taxonomy_id':'Taxonomy_Id','name':'Name','parent_id':'Parent_Id','parent_name':'Parent_Name'})
# Out:
#     Taxonomy_Id                          Name Parent_Id           Parent_Name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df=df.rename(columns={'taxonomy_id':'Taxonomy_Id','name':'Name','parent_id':'Parent_Id','parent_name':'Parent_Name'})
df
# Out:
#     Taxonomy_Id                          Name Parent_Id           Parent_Name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# # separator : sep=' '

# %%
df=pd.read_csv('sample_pipe.txt',sep='|')

df
# Out:
#    First_Name Last_name            Email  Age
# 0  Gyanajyoti   Pradhan  gyana@gmail.com   29
# 1         Sid     nanda    sid@gmail.com   30
# 2       surya     sahoo   sura@gmail.com   29

# %% [markdown]
# # skiprows

# %%
df=pd.read_csv('names.csv',skiprows=[1,2])

df
# Out:
#   First name Last Name           Email  Age
# 0      Surya     Sahoo  sura@gmail.com   29

# %%
df=pd.read_csv('names.csv',skiprows=[2,3])

df
# Out:
#    First name Last Name                Email  Age
# 0  Gyanajyoti   Pradhan  Gyana.dpu@gmail.com   29

# %% [markdown]
# # df.dtypes

# %%
df=pd.read_csv('sample-csv/services.csv')

df.head(5)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# # list of columns

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %% [markdown]
# # selected columns

# %%
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
df[['id','name']].head(5)
# Out:
#    id                               name
# 0   1    Fair Oaks Adult Activity Center
# 1   2   Second Career Employment Program
# 2   3             Senior Peer Counseling
# 3   4           Family Visitation Center
# 4   5  Economic Self-Sufficiency Program

# %%
a=df['name']
type(a)
# Out:
# pandas.core.series.Series

# %%
b=df[['id','name']].head(5)

type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['name']].head(5))  #list of columns means dataframe even if 1 column name selected
# Out:
# pandas.core.frame.DataFrame

# %%
a=df['name']
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # data from link

# %%
df=pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')

df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/zk/rl6r2z6d34z00g5q8tfywxt00000gn/T/ipykernel_7216/3005015386.py in <module>
# ----> 1 df=pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#       2
#       3 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#copy of the link of raw data

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import logging
import inspect

def log(file_name='file1.log', log_level=logging.DEBUG):
        # Set class/method name from where it is called
    logger_name = inspect.stack()[1][3]
    print(logger_name)

        # Create logger
    logger = logging.getLogger(logger_name)
    logger.setLevel(log_level)
    logger.handlers = []
    logger.propagate = False

        # Create file handler
    f = logging.FileHandler(file_name)

        # create formatter
        #formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(name)s : %(message)s',
        #                              datefmt='%m/%d/%Y %I:%M:%S %p')

        # Add formatter to file handler
    f.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(name)s : %(message)s'))

    logger.addHandler(f)
    
log('main.log')
# Out:
# <module>
