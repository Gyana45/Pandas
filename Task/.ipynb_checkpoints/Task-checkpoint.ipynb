# %% [markdown]
# # read from the link ,create a dataframe, if any column have dict values, make them column

# %%
import pandas as pd
import json
import requests

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
raw=requests.get(url)

# %%
raw
# Out:
# <Response [200]>

# %%
type(raw)
# Out:
# requests.models.Response

# %% [markdown]
# # requests.get(url).json()

# %%
data=raw.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#   'id': 1159216249,
#   'node_id': 'PR_kwDOAA0YD84z7u8G',
#   'number': 46222,
#   'title': 'TYP: pd.isna',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
# ...

# %%
type(data)
# Out:
# list

# %%
len(data) #30 dict or nested dict
# Out:
# 30

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#  'id': 1159216249,
#  'node_id': 'PR_kwDOAA0YD84z7u8G',
#  'number': 46222,
#  'title': 'TYP: pd.isna',
#  'user': {'login': 'twoertwein',
#   'id': 6618166,
#   'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/twoertwein',
#   'html_url': 'https://github.com/twoertwein',
#   'followers_url': 'https://api.github.com/users/twoertwein/followers',
# ...

# %%
data[0]['user']
# Out:
# {'login': 'twoertwein',
#  'id': 6618166,
#  'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/twoertwein',
#  'html_url': 'https://github.com/twoertwein',
#  'followers_url': 'https://api.github.com/users/twoertwein/followers',
#  'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#  'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#  'repos_url': 'https://api.github.com/users/twoertwein/repos',
#  'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#  'type': 'User',
# ...

# %% [markdown]
# # json data to DF

# %%
df=pd.DataFrame(data)

df.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/46222  1159216249
# ...

# %%
df.columns.tolist()
# Out:
# ['url',
#  'repository_url',
#  'labels_url',
#  'comments_url',
#  'events_url',
#  'html_url',
#  'id',
#  'node_id',
#  'number',
#  'title',
#  'user',
#  'labels',
#  'state',
#  'locked',
#  'assignee',
#  'assignees',
#  'milestone',
#  'comments',
#  'created_at',
#  'updated_at',
#  'closed_at',
#  'author_association',
#  'active_lock_reason',
#  'draft',
#  'pull_request',
#  'body',
#  'reactions',
#  'timeline_url',
#  'performed_via_github_app']

# %%
df['user'].head(5)
# Out:
# 0    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 1    {'login': 'mvashishtha', 'id': 10712109, 'node...
# 2    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3    {'login': 'rendner', 'id': 414652, 'node_id': ...
# 4    {'login': 'sergiykhan', 'id': 25179211, 'node_...
# Name: user, dtype: object

# %% [markdown]
# # json_normalize()

# %%
pd.json_normalize(df['user']).head(3)
# Out:
#           login        id               node_id  \
# 0  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2   NumberPiOso  46936498  MDQ6VXNlcjQ2OTM2NDk4
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/469364...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 2   https://api.github.com/users/NumberPiOso   https://github.com/NumberPiOso
#
#                                        followers_url  \
# 0  https://api.github.com/users/jbrockmendel/foll...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2  https://api.github.com/users/NumberPiOso/follo...
#
# ...

# %% [markdown]
# # concat column wise

# %%
#pd.concat( [df1,df2],axis=1/2 )

# %%
df=pd.concat( [df.drop('user',axis=1) , pd.json_normalize(df['user']) ] ,axis=1)

# %%
df.head(3)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# ...

# %%
#same column name but diff value (id)are also comming
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'labels', 'state',
#        'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'login', 'id', 'node_id',
#        'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url',
#        'following_url', 'gists_url', 'starred_url', 'subscriptions_url',
#        'organizations_url', 'repos_url', 'events_url', 'received_events_url',
#        'type', 'site_admin'],
#       dtype='object')
